# %% [markdown]
# # Top 1000 Europe Companies

# %%
import pandas as pd

# %%
df=pd.read_csv('/kaggle/input/ft1000/FT1000.csv')

# %%
# Check the first 5 values
df.head(5)
# Out:
#    Rank         Name Ranked2021 Ranked2020    Country              Sector  \
# 0     1      Swappie         No         No    Finland          Technology
# 1     2  Kilo Health         No         No  Lithuania              Health
# 2     3          OCI         No         No         UK  Financial Services
# 3     4     OnlyFans         No         No         UK          Technology
# 4     5        Enpal         No         No    Germany              Energy
#
#      CAGR  Revenue2020  Revenue2017  Employees2020  Employees2017  \
# 0  477.43     97611814       507000            218              1
# 1  450.05     57318766       344428            177             10
# 2  409.59    568322073      4325512             32              4
# 3  393.63    316732986      2652185            800              4
# 4  386.88     56109613       486165            365              9
#
#    FoundingYear
# 0          2016
# 1          2013
# 2          2012
# 3          2016
# 4          2017

# %%
# Check the last 5 values
df.tail(5)
# Out:
#      Rank            Name Ranked2021 Ranked2020  Country  \
# 995   996  peopleForecast         No         No  Germany
# 996   997       Digitalpa         No         No    Italy
# 997   998    Faktenkontor         No         No  Germany
# 998   999          CLAREO        Yes        Yes   France
# 999  1000      Laca Trade        Yes        Yes    Italy
#
#                     Sector   CAGR  Revenue2020  Revenue2017  Employees2020  \
# 995             Technology  36.59      2086411       818658             45
# 996  Management Consulting  36.59      1731340       679440             12
# 997            Advertising  36.59     30967000     12153143            150
# 998                 Retail  36.58     18854708      7399729             53
# 999               Property  36.55     24741510      9717860              5
#
#      Employees2017  FoundingYear
# 995             15          2014
# 996             41          2014
# 997            100          2003
# 998             13          2012
# 999              5          2013

# %%
# Check column and row
df.shape
# Out:
# (1000, 12)

# %%
# Check columns name
df.columns
# Out:
# Index(['Rank', 'Name', 'Ranked2021', 'Ranked2020', 'Country', 'Sector', 'CAGR',
#        'Revenue2020', 'Revenue2017', 'Employees2020', 'Employees2017',
#        'FoundingYear'],
#       dtype='object')

# %%
# Count duplicate
df.duplicated().sum()
# Out:
# 0

# %%
# Check the number of null values in columns
df.isnull().sum()
# Out:
# Rank             0
# Name             0
# Ranked2021       0
# Ranked2020       0
# Country          0
# Sector           0
# CAGR             0
# Revenue2020      0
# Revenue2017      0
# Employees2020    0
# Employees2017    0
# FoundingYear     0
# dtype: int64

# %%
# Check out the data overview
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           1000 non-null   int64
#  1   Name           1000 non-null   object
#  2   Ranked2021     1000 non-null   object
#  3   Ranked2020     1000 non-null   object
#  4   Country        1000 non-null   object
#  5   Sector         1000 non-null   object
#  6   CAGR           1000 non-null   float64
#  7   Revenue2020    1000 non-null   int64
#  8   Revenue2017    1000 non-null   int64
#  9   Employees2020  1000 non-null   int64
#  10  Employees2017  1000 non-null   int64
#  11  FoundingYear   1000 non-null   int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 93.9+ KB

# %%
# Check the descriptive statistics of the variables
df.describe().transpose()
# Out:
#                 count          mean           std         min           25%  \
# Rank           1000.0  5.005000e+02  2.888194e+02        1.00  2.507500e+02
# CAGR           1000.0  7.888195e+01  5.247140e+01       36.55  4.658250e+01
# Revenue2020    1000.0  2.034009e+07  7.771805e+07  1507867.00  3.186724e+06
# Revenue2017    1000.0  4.005901e+06  9.207763e+06   100711.00  6.283870e+05
# Employees2020  1000.0  7.994800e+01  1.614482e+02        1.00  1.400000e+01
# Employees2017  1000.0  2.648000e+01  6.352616e+01        0.00  4.000000e+00
# FoundingYear   1000.0  2.011275e+03  7.665516e+00     1898.00  2.010000e+03
#
#                        50%           75%           max
# Rank               500.500  7.502500e+02  1.000000e+03
# CAGR                61.105  9.352250e+01  4.774300e+02
# Revenue2020    6361153.500  1.662410e+07  2.120072e+09
# Revenue2017    1271955.500  3.549436e+06  1.453982e+08
# Employees2020       30.000  7.000000e+01  1.798000e+03
# Employees2017       10.000  2.300000e+01  7.670000e+02
# FoundingYear      2013.000  2.015000e+03  2.017000e+03

# %%
# Check for unique values
df.nunique()
# Out:
# Rank             1000
# Name             1000
# Ranked2021          2
# Ranked2020          2
# Country            30
# Sector             39
# CAGR              931
# Revenue2020       999
# Revenue2017       999
# Employees2020     225
# Employees2017     122
# FoundingYear       42
# dtype: int64

# %% [markdown]
# ### Ranked2021

# %%
# Checking name unique
df['Ranked2021'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Ranked2021'].value_counts()
# Out:
# No     694
# Yes    306
# Name: Ranked2021, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(15,6))
sns.countplot("Ranked2021",data=df,palette='hls')
plt.xticks(rotation=90)
plt.show()

# %%
label_data=df['Ranked2021'].value_counts()

explode=(0.1,0.1)
plt.figure(figsize=(12,8))
patches,texts,pcts=plt.pie(label_data,labels=label_data.index,
                          colors=['blue','red'],
                          pctdistance=0.65,
                          shadow=True,
                          startangle=90,
                          explode=explode,
                          autopct='%1.1f%%',
                          textprops={'fontsize':25,
                                    'color':'black',
                                    'weight':'bold',
                                    'family':'serif'})
plt.setp(pcts,color='white')
hfont={'fontname':'serif','weight':'bold'}
plt.title('Ranked2021',size=20,**hfont)

centre_circle=plt.Circle((0,0),0.4,fc='white')
fig=plt.gcf()
fig.gca().add_artist(centre_circle)
plt.show()

# %% [markdown]
# ### Ranked2020

# %%
# Name value unique()
df['Ranked2020'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Count values unique
df['Ranked2020'].value_counts()
# Out:
# No     852
# Yes    148
# Name: Ranked2020, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot("Ranked2020",data=df,palette='hls')
plt.xticks(rotation=90)
plt.show()

# %%
label_data=df['Ranked2020'].value_counts()

explode=(0.1,0.1)
plt.figure(figsize=(14,10))
patches,texts,pcts=plt.pie(label_data,
                          labels=label_data.index,
                          colors=['blue','red'],
                          pctdistance=0.65,
                          shadow=True,
                          startangle=90,
                          explode=explode,
                          autopct='%1.1f%%',
                          textprops={'fontsize':25,
                                    'color':'black',
                                    'weight':'bold',
                                    'family':'serif'})
plt.setp(pcts,color='white')
hfont={'fontname':'serif','weight':'bold'}
plt.title("Ranked2020",size=20,**hfont)

centre_circle=plt.Circle((0,0),0.4,fc='white')
fig=plt.gcf()
fig.gca().add_artist(centre_circle)
plt.show()

# %%
# Count Country unique value
df['Country'].unique()
# Out:
# array(['Finland', 'Lithuania', 'UK', 'Germany', 'France', 'Italy',
#        'Sweden', 'Austria', 'Switzerland', 'Norway', 'Poland', 'Belgium',
#        'Latvia', 'The Netherlands', 'Luxembourg', 'Spain', 'Greece',
#        'Portugal', 'Denmark', 'Cyprus', 'Hungary', 'Ireland', 'Slovakia',
#        'Estonia', 'Czech Republic', 'Croatia', 'Romania', 'Bulgaria',
#        'Slovenia', 'Liechtenstein'], dtype=object)

# %%
df['Country'].value_counts()
# Out:
# Italy              235
# Germany            194
# UK                 155
# France             147
# Spain               49
# Poland              34
# Sweden              28
# The Netherlands     19
# Hungary             13
# Czech Republic      11
# Lithuania           11
# Finland             11
# Norway              11
# Belgium             10
# Romania              8
# Bulgaria             7
# Portugal             7
# Slovakia             7
# Croatia              7
# Denmark              6
# Greece               5
# Austria              5
# Ireland              4
# Switzerland          4
# Estonia              4
# Cyprus               3
# Slovenia             2
# Latvia               1
# Luxembourg           1
# Liechtenstein        1
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot('Country',data=df,palette='hls')
plt.xticks(rotation=90)
plt.show()

# %%
# Count unique  name Sector
df['Sector'].unique()
# Out:
# array(['Technology', 'Health', 'Financial Services', 'Energy',
#        'Waste management & recycling', 'Industrial Goods', 'Ecommerce',
#        'Food & Beverage', 'Support Services', 'Fintech', 'Transport',
#        'Fashion', 'Retail', 'Games industry', 'Education', 'Property',
#        'Management Consulting', 'Advertising', 'Interiors',
#        'Pharmaceuticals', 'Personal & Household Goods', 'Automobiles',
#        'Cyber Security', 'Construction', 'Batteries', 'Beauty',
#        'Chemicals & Pharmaceuticals', 'Media', 'Aerospace & Defence',
#        'Sales & Marketing', 'Telecoms', 'Agricultural Commodities',
#        'Travel & Leisure', 'Restaurants', 'Insurance', 'Architecture',
#        'Law', 'Precious metals', 'Sales and Marketing'], dtype=object)

# %%
# Count value Technology
df['Sector'].value_counts()
# Out:
# Technology                      209
# Construction                     89
# Retail                           86
# Ecommerce                        65
# Support Services                 56
# Health                           43
# Energy                           42
# Industrial Goods                 36
# Advertising                      33
# Transport                        28
# Financial Services               28
# Fintech                          26
# Automobiles                      26
# Property                         26
# Management Consulting            22
# Telecoms                         20
# Food & Beverage                  20
# Education                        15
# Interiors                        12
# Waste management & recycling     12
# Media                            11
# Sales & Marketing                10
# Personal & Household Goods       10
# Cyber Security                   10
# Fashion                          10
# Chemicals & Pharmaceuticals       8
# Travel & Leisure                  7
# Agricultural Commodities          7
# Aerospace & Defence               6
# Pharmaceuticals                   5
# Beauty                            5
# Games industry                    4
# Insurance                         3
# Restaurants                       2
# Architecture                      2
# Law                               2
# Precious metals                   2
# Batteries                         1
# Sales and Marketing               1
# Name: Sector, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot("Sector",data=df,palette='hls')
plt.xticks(rotation=90)
plt.show()

# %%
df['FoundingYear'].unique()
# Out:
# array([2016, 2013, 2012, 2017, 2015, 2014, 2011, 2000, 2006, 2004, 2001,
#        2010, 2008, 2009, 2005, 2007, 2003, 1989, 1996, 1976, 1999, 1990,
#        1982, 2002, 1986, 1984, 1994, 1993, 1998, 1979, 1952, 1997, 1983,
#        1977, 1965, 1975, 1956, 1995, 1991, 1938, 1992, 1898])

# %%
df['FoundingYear'].value_counts()
# Out:
# 2016    159
# 2015    122
# 2013    116
# 2014    105
# 2012     88
# 2010     68
# 2017     65
# 2011     65
# 2009     40
# 2008     24
# 2007     22
# 2006     16
# 2005     13
# 2003     13
# 2004     11
# 2001     10
# 2000      9
# 2002      9
# 1999      8
# 1996      6
# 1994      4
# 1984      3
# 1993      3
# 1998      2
# 1997      2
# 1938      1
# 1992      1
# 1991      1
# 1977      1
# 1995      1
# 1956      1
# 1975      1
# 1965      1
# 1990      1
# 1983      1
# 1952      1
# 1979      1
# 1986      1
# 1982      1
# 1976      1
# 1989      1
# 1898      1
# Name: FoundingYear, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot("FoundingYear",data=df,palette='hls')
plt.xticks(rotation=90)
plt.show()

# %%
import plotly.express as px 
import plotly.graph_objects as go
from plotly import tools
from plotly.subplots import make_subplots
from plotly.offline import iplot,init_notebook_mode

# %% [markdown]
# **Ranked**

# %%
plt.figure(figsize=(15,7))
plt.title('2020 vs 2021',fontsize=20)
sns.lineplot(data=df['Ranked2020'],linewidth=2,label='2020')
sns.lineplot(data=df['Ranked2021'],linewidth=2,label='2021',color="green")
plt.show()

# %% [markdown]
# **Revenue**

# %%
plt.figure(figsize=(18,6))
plt.title("Revenue 2020 vs Revenue 2017",fontsize=20)
sns.lineplot(data=df['Revenue2020'],linewidth=2,label='2020')
sns.lineplot(data=df['Revenue2017'],linewidth=2,label='2017',color='r')
plt.show()

# %% [markdown]
# **Employees**

# %%
plt.figure(figsize=(18,6))
plt.title('Employees 2020 vs Employees 2017',fontsize=20)
sns.lineplot(data=df['Employees2020'],linewidth=2,label='2020')
sns.lineplot(data=df['Employees2017'],linewidth=2,label='2017',color='r')
plt.show()

# %% [markdown]
# **CAGR vs FoundingYears**

# %%
plt.figure(figsize=(15,10))
sns.lineplot(data=df,x='FoundingYear',y='CAGR',color='black',alpha=0.9)
plt.title('CAGR vs FoundingYear',fontsize=20)
plt.show()

# %%
sns.jointplot(x='CAGR',y='FoundingYear',data=df,height=10,kind='hex')
plt.title('CAGR vs FoundingYear',fontsize=12)
plt.show()

# %% [markdown]
# **CAGR vs Country & Sector**

# %%
plt.figure(figsize=(12,10))

sns.scatterplot(x='Sector',y='Country',hue='CAGR',data=df)
plt.xticks(rotation=90)
plt.title('CAGR vs Country & Sector',fontsize=20)
plt.show()

# %% [markdown]
# **Sector and Country**

# %%
fig,ax=plt.subplots(figsize=(20,12))
plt.xticks(rotation=90)
ax=sns.stripplot(y='Country',x='Sector',data=df,palette='Pastel1',s=10,marker='P')
plt.title('CAGR vs Сountry & Sector',fontsize = 20)
plt.show()

# %% [markdown]
# **Country and Revenue**

# %%
fig=px.histogram(df,x='Country',color='Country',y='Revenue2020',marginal='box',
                hover_data=df.columns,title='Revenue Distribution Relative To Countries For 2020',
                width=1000,height=500)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="3f9aa742-e43c-475f-b33a-5ce92fe467fa" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f9aa742-e43c-475f-b33a-5ce92fe467fa")) {                    Plotly.newPlot(                        "3f9aa742-e43c-475f-b33a-5ce92fe467fa",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Country=%{x}<br>sum of Revenue2020=%{y}<extra></extra>","legendgroup":"Finland","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Finland","offsetgroup":"Finland","orientation":"v","showlegend":true,"x":["Finland","Finland","Finland","Finland","Finland","Finland","Finland","Finland","Finland","Finland","Finland"],"xaxis":"x","y":[97611814,14338668,2210636,19420672,2501902,11029402,4534346,205312456,8707000,78765693,9409000],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","customdata":[[1,"Swappie","No","No","Technology",477.43,507000,218,1,2016],[18,"Luoto Company","No","No","Technology",253.14,325585,49,6,2016],[69,"AppFollow","No","No","Technology",158.37,128176,73,12,2014],[215,"Newil & Bau","Yes","No","Construction",99.42,2448858,7,1,2006],[241,"Kuori","No","No","Technology",94.5,340000,15,5,2016],[299,"Virta","Yes","Yes","Technology",84.18,1765457,110,23,2013],[306,"Hopkins","No","No","Sales & Marketing",83.16,737936,27,4,2016],[713,"Epassi","No","No","Fintech",48.1,63207258,130,40,2007],[780,"Gapps","Yes","No","Technology",45.1,2850000,34,23,2010],[917,"Axopar Boats","Yes","Yes","Travel & Leisure",39.13,29247774,32,9,2014],[980,"Integrata Oy","Yes","No","Financial Services",37.15,3647000,105,33,2008]],"hovertemplate":"Country=%{x}<br>Rank=%{customdata[0]}<br>Name=%{customdata[1]}<br>Ranked2021=%{customdata[2]}<br>Ranked2020=%{customdata[3]}<br>Sector=%{customdata[4]}<br>CAGR=%{customdata[5]}<br>Revenue2017=%{customdata[6]}<br>Employees2020=%{customdata[7]}<br>Employees2017=%{customdata[8]}<br>FoundingYear=%{customdata[9]}<extra></extra>","legendgroup":"Finland","marker":{"color":"#636efa"},"name":"Finland","notched":true,"offsetgroup":"Finland","showlegend":false,"x":["Finland","Finland","Finland","Finland","Finland","Finland","Finland","Finland","Finland","Finland","Finland"],"xaxis":"x2","yaxis":"y2","type":"box"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Country=%{x}<br>sum of Revenue2020=%{y}<extra></extra>","legendgroup":"Lithuania","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Lithuania","offsetgroup":"Lithuania","orientation":"v","showlegend":true,"x":["Lithuania","Lithuania","Lithuania","Lithuania","Lithuania","Lithuania","Lithuania","Lithuania","Lithuania","Lithuania","Lithuania"],"xaxis":"x","y":[57318766,6801734,156623915,8900000,13028856,25860664,25040954,1778249,1578677,3905042,1551468],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","customdata":[[2,"Kilo Health","No","No","Health",450.05,344428,177,10,2013],[168,"Kamado Bono","No","No","Personal & Household Goods",109.88,735758,7,2,2013],[179,"Nord Security","No","No","Cyber Security",106.85,18035029,1000,350,2012],[352,"Nova rent","No","No","Industrial Goods",77.18,1600000,37,9,2016],[554,"Poppri Fashion Auctions","Yes","No","Ecommerce",56.7,3386414,94,45,2012],[581,"Hostinger","Yes","Yes","Technology",54.92,6955394,780,80,2004],[662,"Oxylabs.io","No","No","Technology",50.26,7381686,245,57,2015],[790,"Softneta","No","No","Health",44.4,590642,30,24,2007],[900,"Sapiegos Klinika","No","No","Health",39.67,579436,24,14,2014],[938,"Rivile","No","No","Technology",38.58,1467195,24,20,1992],[971,"Riotloc","No","No","Games industry",37.49,596906,1,1,2016]],"hovertemplate":"Country=%{x}<br>Rank=%{customdata[0]}<br>Name=%{customdata[1]}<br>Ranked2021=%{customdata[2]}<br>Ranked2020=%{customdata[3]}<b ...

# %%
fig=px.histogram(df,x='Country',y="Revenue2017",marginal='box',hover_data=df.columns,
                title="Revenue Distribution Relative To Countries For 2017",
                width=1000,height=500)
fig.show()
# Out:
# <div>                            <div id="f4d334e2-2d40-4dcc-8612-bfce3d6b8859" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4d334e2-2d40-4dcc-8612-bfce3d6b8859")) {                    Plotly.newPlot(                        "f4d334e2-2d40-4dcc-8612-bfce3d6b8859",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Country=%{x}<br>sum of Revenue2017=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Finland","Lithuania","UK","UK","Germany","Germany","UK","France","Italy","Sweden","Austria","France","Italy","UK","Germany","UK","Switzerland","Finland","Austria","France","Norway","Poland","Italy","UK","Italy","UK","Norway","UK","Belgium","Latvia","Italy","Germany","The Netherlands","Luxembourg","Germany","France","Spain","Poland","Germany","Italy","UK","France","The Netherlands","Germany","UK","Italy","UK","UK","Sweden","Poland","France","Greece","France","UK","UK","Germany","UK","Italy","Germany","Italy","The Netherlands","UK","Germany","France","Italy","Italy","Spain","Italy","Finland","Poland","Poland","Germany","France","Italy","UK","Italy","UK","Italy","France","UK","Germany","UK","UK","Italy","Portugal","France","Denmark","Italy","UK","UK","Italy","Germany","Sweden","Italy","UK","Italy","Spain","Germany","UK","France","UK","Cyprus","Italy","The Netherlands","Portugal","Germany","Hungary","Norway","Belgium","UK","Italy","Germany","Hungary","Italy","Italy","Germany","France","Ireland","France","Italy","Germany","Germany","France","Italy","UK","UK","Poland","Slovakia","Italy","Italy","Sweden","UK","Germany","France","Denmark","Germany","Italy","France","France","France","Germany","Estonia","Italy","Germany","Denmark","Italy","Italy","The Netherlands","Spain","UK","Germany","The Netherlands","Italy","UK","Italy","UK","Hungary","Germany","UK","Spain","France","Sweden","Germany","Sweden","Ireland","UK","Italy","Lithuania","Spain","Czech Republic","Germany","Italy","Germany","Denmark","Sweden","Poland","Italy","Spain","Lithuania","The Netherlands","Spain","Ireland","Greece","Italy","France","UK","The Netherlands","France","Germany","Italy","Croatia","Spain","Italy","Germany","Hungary","Czech Republic","Denmark","Estonia","Italy","France","UK","UK","Germany","Italy","UK","Sweden","Germany","UK","Germany","Germany","France","Italy","UK","Germany","Finland","Spain","Sweden","Italy","Italy","UK","Sweden","Germany","Italy","Germany","Croatia","Denmark","UK","Germany","Germany","Greece","UK","Germany","UK","Germany","UK","Italy","Poland","Germany","Germany","Germany","Finland","Sweden","UK","France","France","Italy","Spain","Sweden","UK","Germany","UK","Germany","France","Italy","Spain","UK","Poland","Italy","Italy","UK","Italy","France","UK","Italy","UK","Norway","UK","Italy","Germany","Italy","Spain","Belgium","Sweden","Czech Republic","Italy","UK","Spain","Germany","France","France","Sweden","Germany","Italy","Germany","Germany","Romania","Croatia","The Netherlands","Italy","Germany","Italy","Czech Republic","Portugal","Germany","The Netherlands","UK","UK","France","Finland","Italy","France","UK","Hungary","France","Czech Republic","Finland","Italy","UK","Italy","Germany","UK","Italy","Germany","Italy","Norway","France","Germany","UK","Romania","Italy","Germany","Italy","France","France","Cyprus","Germany","Italy","The Netherlands","France","Italy","UK","France","Germany","Italy","Germany","Germany","Germany","Italy","France","Italy","UK","UK","Germany","Italy","Germany","UK","Italy","UK","Austria","Italy","France","Lithuania","Czech Republic","Italy","Poland","France","UK","France","Italy","UK","Poland","UK","Italy","Italy","UK","Italy","Ita ...

# %%
fig=px.histogram(df,x='Sector',color='Sector',y='Revenue2020',
                 marginal='box',hover_data=df.columns,
                 title='Sector Revenues For 2020', width=1000,height=500)
fig.show()
# Out:
# <div>                            <div id="f8d79192-2504-4935-8fc9-01c88c021131" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8d79192-2504-4935-8fc9-01c88c021131")) {                    Plotly.newPlot(                        "f8d79192-2504-4935-8fc9-01c88c021131",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Sector=%{x}<br>sum of Revenue2020=%{y}<extra></extra>","legendgroup":"Technology","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Technology","offsetgroup":"Technology","orientation":"v","showlegend":true,"x":["Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology"],"xaxis":"x","y":[97611814,316732986,24484879,9034926,21455864,7234981,14338668,5926970,4864178,8951132,17158962,64223085,7435887,15365580,57670541,2210636,3999023,1825546,40813930,11761268,3871782,10019903,12571314,3320479,8730000,6890000,1721315,3031099,1629099,10049610,26894501,9923965,3332661,24721755,5743440,3597000,221393889,15486451,1715334,5639953,2027170,72044361,11499031,19446429,9391760,8609941,22386000,1978128,2633664,11087980,1973775,391 ...

# %% [markdown]
# **Sector and Revenue**

# %%
fig= px.histogram(df, x='Sector', color='Sector',y='Revenue2017',marginal='box',
                    hover_data=df.columns,title= 'Sector revenues for 2017',
                    width=1000, height=500)
fig.show()
# Out:
# <div>                            <div id="ca0b3216-b723-4f55-9a9a-f13a08111fbe" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca0b3216-b723-4f55-9a9a-f13a08111fbe")) {                    Plotly.newPlot(                        "ca0b3216-b723-4f55-9a9a-f13a08111fbe",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Sector=%{x}<br>sum of Revenue2017=%{y}<extra></extra>","legendgroup":"Technology","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Technology","offsetgroup":"Technology","orientation":"v","showlegend":true,"x":["Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology"],"xaxis":"x","y":[507000,2652185,392055,155406,454975,149397,325585,229713,194090,379771,757323,3188715,376519,858482,3306795,128176,255062,107492,2474341,742746,249176,672821,925527,247465,664000,530667,159128,242368,131691,815690,2201178,855321,288095,2326082,522712,330500,21098843,1521010,167000,552355,204620,7450099,1217338,2096570,1052796,1057443,2531000,228982,327218,1349733,249818,500440,504357,548180,274966,755191,26626422,2708983,975140,3400 ...

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(data=df,x='Sector',y="Revenue2020",hue='Country',legend=True)
plt.xticks(rotation=90)
plt.title('Revenue for 2020 vs countries & sectors', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(18,12))
sns.scatterplot(data=df, x='Sector', y='Revenue2017', hue='Country', legend=True)
plt.xticks(rotation=90)
plt.title('Revenue for 2017 vs countries & sectors',fontsize = 20)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.kdeplot(df['CAGR'],df['Revenue2020'],shade=True,cmap='Reds',shade_lowest=False)
plt.title('CAGR vs Revenue2020',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.kdeplot(df['CAGR'],df['Revenue2017'],shade=True,cmap='Reds', shade_lowest=False)
plt.title('CAGR vs Revenue2017',fontsize = 20)
plt.show()

# %%
#pip install plotly==5.13.0

# %%
fig = px.box(df, x='Sector', color='Sector', y='Employees2017',
             title='Distribution and analysis of the number of employees by sector in 2017')
fig.show()
# Out:
# <div>                            <div id="4e388337-89df-40c1-9b54-0eb29b6b2008" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e388337-89df-40c1-9b54-0eb29b6b2008")) {                    Plotly.newPlot(                        "4e388337-89df-40c1-9b54-0eb29b6b2008",                        [{"alignmentgroup":"True","hovertemplate":"Sector=%{x}<br>Employees2017=%{y}<extra></extra>","legendgroup":"Technology","marker":{"color":"#636efa"},"name":"Technology","notched":false,"offsetgroup":"Technology","orientation":"v","showlegend":true,"x":["Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology"],"x0":" ","xaxis":"x","y":[1,4,5,13,4,2,6,22,16,3,7,8,14,28,47,12,40,4,22,20,2,0,9,6,44,24,2,7,6,9,55,47,1,75,48,5,399,32,8,37,2,40,37,767,3,32,25,2,8,4,3,4,15,5,7,6,92,16,25,5,2,12,14,44,156,15,2,10,22,7,1,8,1,23,23,4,8,39,9,2,9,8,2,38,13,28,7,26,90,12,25,5,8,16,72,8,16,25,37,50,266,33,10,14,10,51,9,8,199,12,17,15,15,9,17,14,3,11,8,4,6,35,187,2,7,185,17,80,26,82,27,1,16,15,10,62,11,4,2,40,4,71,57,6,230,34,30,39,62,7,150,211,9,48,16,1,3,9,60,11,28,13,90,23,29,8,50,30,15,5,2,140,31,8,20,23,18,1,1 ...

# %%
fig = px.box(df, x='Sector', color='Sector', y='Employees2020',
             title= 'Distribution and analysis of the number of employees by sector in 2020')
fig.show()
# Out:
# <div>                            <div id="b45505a0-5aae-478f-8001-c9fdf6d274b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b45505a0-5aae-478f-8001-c9fdf6d274b7")) {                    Plotly.newPlot(                        "b45505a0-5aae-478f-8001-c9fdf6d274b7",                        [{"alignmentgroup":"True","hovertemplate":"Sector=%{x}<br>Employees2020=%{y}<extra></extra>","legendgroup":"Technology","marker":{"color":"#636efa"},"name":"Technology","notched":false,"offsetgroup":"Technology","orientation":"v","showlegend":true,"x":["Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology","Technology"],"x0":" ","xaxis":"x","y":[218,800,117,251,34,41,49,56,124,38,63,70,61,138,274,73,190,12,138,99,32,26,23,45,122,54,7,55,10,18,310,190,25,563,164,44,1798,292,40,95,26,288,155,932,41,176,226,12,44,24,18,25,55,30,43,18,650,18,107,15,14,36,118,218,801,74,36,40,142,35,6,9,3,22,110,55,41,82,27,9,40,50,7,88,32,76,15,85,234,62,59,30,27,25,164,30,60,47,90,195,773,70,32,23,81,137,25,22,637,74,55,87,41,18,56,31,13,25,35,9,10,70,364,3,14,426,61,780,119,241,76,9,28,32,22,217,25,12,2,89,11,213,245,7,720,106,7 ...
